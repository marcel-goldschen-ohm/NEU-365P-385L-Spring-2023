# %% [markdown]
# # Homework - Linear Regression (9 pts)

# %% [markdown]
# ---
# ### Collaborators
# You MUST include a bulleted list with the full names of everyone you collaborated with on this assignment.
# - Jane Doe
# - John Doe

# %% [markdown]
# ---
# 1. (3 pts) For the diabetes dataset in `diabetes.csv` (make sure you copy this file from the assignments folder to the folder where you have this homework notebook file), compute the weights (i.e., slopes) and intercept for a linear model that predicts diabetes progression based on the other 10 features after the features have been standardized.

# %% [markdown]
# ---
# 2. (3 pts) Use bootstrap to estimate 95% confidence intervals for each weight (slope) in the model above.

# %% [markdown]
# ---
# 3. (3 pts) Make bar plot of the model weights with errorbars indicating their 95% confidence limits.
